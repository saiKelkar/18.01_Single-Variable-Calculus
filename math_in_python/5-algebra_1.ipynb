# %%
import numpy as np
import sympy as sym
from IPython.display import display, Math

# %%
x = sym.symbols('x')

expr = 2 * x + 4 - 9
sym.solve(expr)
# Out:
# [5/2]

# %%
display(Math(f'\\text{{The solution to }} {sym.latex(expr)} \\text{{ is }} {sym.latex(sym.solve(expr)[0])}'))
# Out:
# $\displaystyle \text{The solution to } 2 x - 5 \text{ is } \frac{5}{2}$

# %%
expr = x**2 - 4 
sol = sym.solve(expr)

for i in range(len(sol)):
    display(Math(f'\\text{{The solution to }} {sym.latex(expr)} \\text{{ is }} {sym.latex(sol[i])}'))
# Out:
# $\displaystyle \text{The solution to } x^{2} - 4 \text{ is } -2$
# $\displaystyle \text{The solution to } x^{2} - 4 \text{ is } 2$

# %%
y = sym.symbols('y')

expr = x / 4 - x * y + 5
sym.solve(expr, x)

display(Math(f'\\text{{The solution to }} {sym.latex(expr)} \\text{{ for }} x \\text{{ is }} {sym.latex(sym.solve(expr, x)[0])}'))
# Out:
# $\displaystyle \text{The solution to } - x y + \frac{x}{4} + 5 \text{ for } x \text{ is } \frac{20}{4 y - 1}$

# %%
q = sym.symbols('q')

expr = 3 * q + 4 / q + 3 - 5 * q - 1 / q - 1
display(Math(f'\\text{{The solution to }} {sym.latex(expr)} \\text{{ for }} q \\text{{ is }} {sym.latex(sym.solve(expr, q))}'))
# Out:
# $\displaystyle \text{The solution to } - 2 q + 2 + \frac{3}{q} \text{ for } q \text{ is } \left[ \frac{1}{2} - \frac{\sqrt{7}}{2}, \  \frac{1}{2} + \frac{\sqrt{7}}{2}\right]$

# %%
from sympy.abc import x

term_1 = (4 * x + 5)
term_2 = x

print(term_1 * term_2)
print(sym.expand(term_1 * term_2))
display(Math(sym.latex(sym.expand(term_1 * term_2))))
# Out:
# x*(4*x + 5)
# 4*x**2 + 5*x
# $\displaystyle 4 x^{2} + 5 x$

# %%
term_3 = x - 7

display(Math(sym.latex(term_1 * term_3)))
display(Math(sym.latex(sym.expand(term_1 * term_3))))
# Out:
# $\displaystyle \left(x - 7\right) \left(4 x + 5\right)$
# $\displaystyle 4 x^{2} - 23 x - 35$

# %%
from sympy.abc import y 

expr = x * (2 * y ** 2 - 5 ** x / x)
display(Math(sym.latex(expr)))
display(Math(sym.latex(sym.expand(expr))))
# Out:
# $\displaystyle x \left(- \frac{5^{x}}{x} + 2 y^{2}\right)$
# $\displaystyle - 5^{x} + 2 x y^{2}$

# %%
expr = (4 + x) * (2 - y)
display(Math(sym.latex(expr)))
display(Math(sym.latex(sym.expand(expr))))
# Out:
# $\displaystyle \left(2 - y\right) \left(x + 4\right)$
# $\displaystyle - x y + 2 x - 4 y + 8$

# %%
for i in range(3):
    for j in range(3):
        display(Math(f'{sym.latex(sym.expand(expr))} \\text{{ evaluated at }} x={i}, y={j} \\text{{ is }} {sym.latex(expr.subs({x: i, y: j}))}'))
# Out:
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=0, y=0 \text{ is } 8$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=0, y=1 \text{ is } 4$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=0, y=2 \text{ is } 0$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=1, y=0 \text{ is } 10$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=1, y=1 \text{ is } 5$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=1, y=2 \text{ is } 0$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=2, y=0 \text{ is } 12$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=2, y=1 \text{ is } 6$
# $\displaystyle - x y + 2 x - 4 y + 8 \text{ evaluated at } x=2, y=2 \text{ is } 0$
