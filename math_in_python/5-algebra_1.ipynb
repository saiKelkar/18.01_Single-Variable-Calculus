# %%
import numpy as np
# Out:
# Running cells with '.venv (Python -1.-1.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/saikelkar/Documents/18.01_Single-Variable-Calculus/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
