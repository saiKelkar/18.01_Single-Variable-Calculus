# %%
import numpy as np

# %%
# Lists
# Numpy arrays

# %%
aList = [0, 1, 2, 3, 4, 5]
aList

# %%
listList = [3, ['3', '4', '5'], 5.5, [4, 5, 6]]
listList

# %%
aList_np = np.array(aList)
aList_np
print(aList_np)

# %%
aList * 3 # list is printed 3 times

# %%
aList_np * 3 # element wise multiplication

# %%
# enumerate (i, x) <-- (index, data stored at that index)
for i, x in enumerate([3, ['3', '4', '5'], 5.5, [4, 5, 6]]):
    print(f'List element {i} is {x} and is of type {type(x)}')
