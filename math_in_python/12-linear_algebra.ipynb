# %%
# row and clolumn vectors
# vector -- ordered list of numbers
# dimensionality -- number of components in a vector

import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from IPython.display import display, Math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       2 # vector -- ordered list of numbers
#       3 # dimensionality -- number of components in a vector
#       4
#       5 import numpy as np
# ----> 6 import matplotlib.pyplot as plt
#       7 import sympy as sp
#       8 from IPython.display import display, Math
#
# ModuleNotFoundError: No module named 'matplotlib'
