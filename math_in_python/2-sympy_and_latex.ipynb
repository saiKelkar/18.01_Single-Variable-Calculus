# %%
import sympy as sym 
sym.init_printing()
from IPython.display import display, Math

# %%
x, y = sym.symbols('x, y')
y + 4
# Out:
# y + 4

# %%
display(x ** y)
# Out:
#  y
# x

# %%
# Difference between symbolic and numeric
import numpy as np
display(np.sqrt(2))
display(sym.sqrt(2))
# Out:
# np.float64(1.4142135623730951)
# √2

# %%
display(Math('y \\times x^2'))
display(sym.sqrt(4) * x)
display(sym.sqrt(x) * sym.sqrt(x))
# Out:
# $\displaystyle y \times x^2$
# 2⋅x
# x

# %%
display(Math('\\sigma = \\mu \\times \\sqrt{5x+3z-17z}'))
# Out:
# $\displaystyle \sigma = \mu \times \sqrt{5x+3z-17z}$

# %%
display(Math('x_{mm} + y^{n+2k-15}'))
display(Math('\\text{The answer to this equation is }\\frac{1 + x}{2v - s^{t + 4r}}'))
# Out:
# $\displaystyle x_{mm} + y^{n+2k-15}$
# $\displaystyle \text{The answer to this equation is }\frac{1 + x}{2v - s^{t + 4r}}$

# %% [markdown]
# # This is a markdown cell
# This cell is not for running actual Python code
#
# $$\frac{1 + x}{2v - s^{t + 4r}}$$

# %% [markdown]
# ## A subcell

# %% [markdown]
# ### Even smaller text

# %%
display(Math('4x + 5y - 8z = 17'))
display(Math('\\sin ({2 \\pi ft + \\theta})'))
display(Math('e = mc^2'))
display(Math('\\frac {4 + 5x^2}{(1 + x)(1 - x)}'))
# Out:
# $\displaystyle 4x + 5y - 8z = 17$
# $\displaystyle \sin ({2 \pi ft + \theta})$
# $\displaystyle e = mc^2$
# $\displaystyle \frac {4 + 5x^2}{(1 + x)(1 - x)}$
